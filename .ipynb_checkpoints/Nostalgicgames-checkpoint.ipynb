# %%
import random
print('''The Games that the user can play are :
1.Rock-Paper-Scissor
2.Coin Flip''')
g=int(input('Choose the game, you want to play:'))
if g==1:
    print("Rules for the Rock-Paper-Scissor game are given below:")
    print("In case of Rock vs Paper 'Paper Wins'")
    print("In case of Rock vs Scissor 'Scissor Wins'")
    print("In case of Paper vs Scissor'Scissor Wins'")
    print('')
    print('The choices that the user can chosse are :')
    print('1.Paper✋🏻')
    print('2.Scissor✌🏻')
    print('3.Rock👊🏻')
    user=int(input('Enter your choice:'))
    while user<1 or user>3:
        print('Invalid Input,Please enter your choice again')
        usser=int(input('Enter your choice:'))
    print(' ')
    if user==1:
        print('You have selected: Paper✋🏻')
        uc='Paper✋🏻'
    elif user==2:
        print('You have selected: scissor✌🏻')
        uc='Scissor✌🏻'
    elif user==3:
        print('You have selected: Rock👊🏻')
        uc='Rock👊🏻'
    print(' ')
    comp=random.randint(1,4)
    if comp==1:
        print('System has selected: Paper✋🏻')
        comp_c='Paper✋🏻'
    elif comp==2:
        print('System has selected: Scissor✌🏻')
        comp_c='Scissor✌🏻'
    else:
        comp==3
        print('System has selected: Rock👊🏻')
        comp_c='Rock👊🏻'
    print(' ')
    print(uc,'V/S',comp_c)
    print(' ')
    if comp==user:
        print("It's a Draw between the User and the System")
        print(' ')
    elif (user==1 and comp==3) or (user==2 and comp==3) or (user==3 and comp==2):
        print(uc,'Wins')
        print('The User Wins')
    elif (user==1 and comp==2) or (user==2 and comp==1) or (user==3 and comp==1):
        print(comp_c,'Wins')
        print('The System Wins')
elif g==2:
    print('''You can either play with your friend or you can play with the system
    Enter 1 if you want to play with your Friend
    Enter 2 if you want to play with the System''')
    x=int(input('Enter your choice:'))
    if x==1:
        print('''Press  1 to select Heads,Press 2 to select Tails''')
        fp=int(input("First player should enter his choice:"))
        if fp==1:
            fp_n='HEADS'
        elif fp==2:
            fp_n='TAILS'
        else:
            print('Invalid choice,Please choose from Heads and Tails')
        sp=int(input('Second player should enter his choice:'))
        if sp==1:
            sp_n='HEADS'
        elif sp==2:
            sp_n='TAILS'
        else:
            print('Invalid choice,Please choose from Heads and Tails')

        if fp!=sp:
            a=random.randint(1,2)
            if a==fp:
                print(fp_n,'First Player Wins')
            elif a==sp:
                print(sp_n,'Second Player Wins')
        else :
            print("It's a Draw between Player 1 and Player 2")
    elif x==2:
        print('''Press  1 to select Heads,Press 2 to select Tails''')
        fp=int(input('Player should enter his choice:'))
        if fp==1:
            fp_n='HEADS'
        elif fp==2:
            fp_n='TAILS'
        else:
            print('Invalid choice,Please choose from Heads and Tails')
        a=random.randint(1,2)
        if a==1:
            a_n='HEADS'
        else:
            a_n='TAIL'
        if a==fp:
            print(fp_n,'The Player Wins')
        elif a!=fp:
            print(a_n,'The System Wins')
        else:
            print("It's Draw between the System and the Player")
    else:
        print('Wrong Input,Please choose from option 1 and option 2')
# Out:
# The Games that the user can play are :
# 1.Rock-Paper-Scissor
# 2.Coin Flip
# Choose the game, you want to play:3
